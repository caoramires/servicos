# %% [markdown]
# # Estudo dos dados da base de dados servicosxis.db
#
# Carlos Ramires
#
# inicio: 21/11/2023
# termino: 22/11/2023
#
# Busca das distribuições para Entrada de Chamados e  Tecnicos para uma simulação de capacity
#
# Tabelas importantes da servicosxos.db
#
# servicos: Base raw \
# serv_campo: base só com os serviços de campo \
# qtd_servicos_'unidade': apresenta a distribuição dos serviços por mês de 2020-01 a 2023-07 \
# qtd_tec_mes: Mostra a quantidade de técnicos por unidade por mês\
# resumo_servicos: Mostra a quantidade por serviços, por unidade, no periodo\
# servicos_mensal: Serviços de campo com Ano_Mes\
# servicos_mes: Tem o total de serviços por mes, por unidade\
# servicos_tec_mes: Relaciona o número de serviços, por serviço, por técnico, por mes\
#
# # Criadas as tabela serv_total_mensal - serv_top_tec,
#
# # estudo das médias e Gráfico dos totais por técnico
#
# A partir dos totais de serviços dos técnicos com melhor média em todas as unidades
#
# ### Criada tabela serv_total_mensal
#
# Com os serviços totais por técnico por mês
#
# ### Criada tabela serv_top_tec
#
# Com os serviços por Unidade / Tópico / Técnico Top / Mes
#
# ### Assumption
#
# #### Tempo médio de atendimento de um pedido
#
# Considerando o tempo entre abertura e encerramento do chamado tem-se o tempo total do atendimento.
#
# Em
#
# servicos_mes > Total de serviços/mes
#
# serv_campo > serviços, causa, designado, duração
#
# Dados espúrios serão descartados da seguinte maneira:
#
#
#
#
# #### Tempo médio de execução de um serviço
#
# Um mês tem 176 horas sendo 22 horas de instrução o que define 154 horas úteis
#
# Considerando um fator de ponderação fp, 154 horas trabalhadas no mês e o número de serviços entregues, temos:
#
# num_instal * fp + num_vt * fp + num_ret * fp + num_mud * fp = 154
#
# Portanto, o fp de cada técico será:
#
# fp =   154 / (num_instal + num_vt + num_ret + num_mud)
#
# ou seja, o tempo médio dispendido para cada serviço deverá ser tm = num_serv * fp
#
# ### Número de Equipes disponíveis por mês
#
# Em [serv_campo] identificar equipes válidas por unidade e contar equipes ativas mês a mês

# %%
import sqlite3
import pandas as pd

# Carrega a tabela servicos da base servicosxis.db para um dataframe

# Cria a conexão
cnx = sqlite3.connect('servicosxis.db')

# carrega tabela servicos em df
df = pd.read_sql_query("SELECT * FROM serv_campo", cnx)

tecnicos_df = pd.read_sql_query("SELECT * FROM servicos_tec_mes", cnx)

tec_unidade_df = pd.read_sql_query("SELECT * FROM tecnicos_unidade", cnx)

cnx.close()

# %%
# Separar técnicos por unidade

list = ['CPE']
df_tec = tec_unidade_df.loc[tec_unidade_df['Unidade'].isin(list)]


# Cria um conjunto de elementos únicos
tec_alg = set(df_tec['Tecnicos'])
    

df = tecnicos_df.loc[tecnicos_df['Unidade'].isin(list)]

# %%
# top_alg = ['henrique.costa', 'henrique.silva' 'diego.morais', 'erivaldo.silva', 'ricardo.neres', 'lucas.coimbra',
#           'lander.lucas', 'italo.aires', 'alessandro.almeida', 'cleiton.oliveira', 'douglas.santos'
#           ]

# top_nga = ['carlos.augusto', 'wendel.silva', 'dejalma.cardoso', 'edvaldo.oliveira', 'leonardo.ferreira'
#               'henrique.soares', 'marcelo.martins', 'hainer.sohn', 'wellington.carlos', 'leno.pereira'
#               'leonardo.marques', 'thiago.pires']

# top_pmj = ['diego.dias', 'irineu.souza', 'ivanildo.ribeiro', 'valdinei.cavalcante', 'cosme.damasceno'
#           'genival.melo']
# top_cpe = ['max.oliveira' ]

# top_rbh = ['juliano.lopes', 'ugleicon.silva', 'guilherme.antunes']

top = ['henrique.costa', 'henrique.silva' 'diego.morais', 'erivaldo.silva', 'ricardo.neres', 'lucas.coimbra',
          'lander.lucas', 'italo.aires', 'alessandro.almeida', 'cleiton.oliveira', 'douglas.santos,'
          'carlos.augusto', 'wendel.silva', 'dejalma.cardoso', 'edvaldo.oliveira', 'leonardo.ferreira'
            'henrique.soares', 'marcelo.martins', 'hainer.sohn', 'wellington.carlos', 'leno.pereira'
            'leonardo.marques', 'thiago.pires', 'diego.dias', 'irineu.souza', 'ivanildo.ribeiro', 
           'valdinei.cavalcante', 'cosme.damasceno','genival.melo','max.oliveira', 'juliano.lopes', 
            'ugleicon.silva', 'guilherme.antunes'
      ]

# %%
# Separar serviços dos técnicos top 

list = ['henrique.costa', 'henrique.silva', 'diego.morais', 'erivaldo.silva', 'ricardo.neres', 'lucas.coimbra',
          'lander.lucas', 'italo.aires', 'alessandro.almeida', 'cleiton.oliveira', 'douglas.santos',
          'carlos.augusto', 'wendel.silva', 'dejalma.cardoso', 'edvaldo.oliveira', 'leonardo.ferreira',
            'henrique.soares', 'marcelo.martins', 'hainer.sohn', 'wellington.carlos', 'leno.pereira',
            'leonardo.marques', 'thiago.pires', 'diego.dias', 'irineu.souza', 'ivanildo.ribeiro', 
           'valdinei.cavalcante', 'cosme.damasceno','genival.melo','max.oliveira', 'juliano.lopes', 
            'ugleicon.silva', 'guilherme.antunes'
      ]

df_top = tecnicos_df.loc[tecnicos_df['Usuario_Designado'].isin(list)]

# %%
# Separa Técnicos e seus serviços

display(df_top)
# criar uma lista serviços por mes por técnico
# Out:
#       index Unidade                                   Topico  \
# 2         2     ALG         (Instalação) proceder Instalação
# 4         4     ALG         (Instalação) proceder Instalação
# 6         6     ALG         (Instalação) proceder Instalação
# 10       10     ALG         (Instalação) proceder Instalação
# 15       15     ALG  (RetiradaEquip) Retirada de equipamento
# ...     ...     ...                                      ...
# 3969   3969     NAA           (VisitaTécnica) Visita Técnica
# 3975   3975     NAA           (VisitaTécnica) Visita Técnica
# 3983   3983     NAA         (Instalação) proceder Instalação
# 4000   4000     NAA         (Instalação) proceder Instalação
# 4004   4004     NAA           (VisitaTécnica) Visita Técnica
#
#       Usuario_Designado  Ano_Mes  Total
# 2        henrique.silva  2019-11    1.0
# 4        henrique.costa  2019-12   38.0
# 6        henrique.silva  2019-12   34.0
# 10         diego.morais  2019-12   11.0
# ...

# %%
# Cria uma df com as colunas Ano_Mes e total de serviços
#

df_mensal = df_top.groupby('Ano_Mes')
total = df_mensal['Total'].sum()
total_di = total.to_dict()
# cria um df de um dicionario
df_total_mensal = pd.DataFrame.from_dict(total_di, orient='index', columns=['Total'])
# define o indice Ano_Mes
df_total_mensal.index.names = ['Ano_Mes']

print(df_total_mensal)
# Out:
#           Total
# Ano_Mes
# 2019-11     1.0
# 2019-12    91.0
# 2020-01   225.0
# 2020-02   395.0
# 2020-03   509.0
# 2020-04   709.0
# 2020-05  1065.0
# 2020-06  1027.0
# 2020-07  1334.0
# 2020-08  1402.0
# 2020-09  1578.0
# 2020-10  1514.0
# 2020-11  1586.0
# 2020-12  1531.0
# 2021-01  1842.0
# 2021-02  1889.0
# 2021-03  2158.0
# 2021-04  2026.0
# 2021-05  2170.0
# 2021-06  1936.0
# 2021-07  1847.0
# 2021-08  1598.0
# 2021-09  1545.0
# 2021-10  1421.0
# 2021-11  1479.0
# 2021-12  1396.0
# 2022-01  1379.0
# 2022-02  1232.0
# 2022-03  1489.0
# 2022-04  1181.0
# 2022-05  1418.0
# 2022-06  1200.0
# 2022-07  1145.0
# 2022-08  1237.0
# 2022-09  1074.0
# 2022-10  1073.0
# 2022-11   894.0
# 2022-12   939.0
# 2023-01   905.0
# 2023-02   726.0
# 2023-03   889.0
# 2023-04   718.0
# 2023-05   809.0
# 2023-06   624.0
# 2023-07   758.0

# %%
# encontrar a média de serviços por mês no período de vida
# e colocar numa lista

tecnicos = ['henrique.costa', 'henrique.silva', 'diego.morais', 'erivaldo.silva', 'ricardo.neres', 'lucas.coimbra',
          'lander.lucas', 'italo.aires', 'alessandro.almeida', 'cleiton.oliveira', 'douglas.santos',
          'carlos.augusto', 'wendel.silva', 'dejalma.cardoso', 'edvaldo.oliveira', 'leonardo.ferreira',
            'henrique.soares', 'marcelo.martins', 'hainer.sohn', 'wellington.carlos', 'leno.pereira',
            'leonardo.marques', 'thiago.pires', 'diego.dias', 'irineu.souza', 'ivanildo.ribeiro', 
           'valdinei.cavalcante', 'cosme.damasceno','genival.melo','max.oliveira', 'juliano.lopes', 
            'ugleicon.silva', 'guilherme.antunes'
          ]



for tecnico in tecnicos:
    # separa df só com o técnico e seus serviços
    df_tec = df_top['Usuario_Designado']== tecnico
    df_tec = df_top[df_tec]
    df_group = df_tec.groupby('Ano_Mes')
    total = df_group['Total'].sum()
    total_di = total.to_dict()
    
    # cria um df de um dicionario
    
    df_total = pd.DataFrame.from_dict(total_di, orient='index', columns=[tecnico])
    # define o indice Ano_Mes
    df_total.index.names = ['Ano_Mes']

    df_total_mensal = df_total_mensal.merge(df_total, on='Ano_Mes', how='left')
    
df_total_mensal = df_total_mensal.fillna(0)
display(df_total_mensal)
# Out:
#           Total  henrique.costa  henrique.silva  diego.morais  erivaldo.silva  \
# Ano_Mes
# 2019-11     1.0             0.0             1.0           0.0             0.0
# 2019-12    91.0            42.0            34.0          12.0             3.0
# 2020-01   225.0            74.0            56.0          22.0            44.0
# 2020-02   395.0           107.0            63.0           3.0            67.0
# 2020-03   509.0           135.0            56.0           1.0            76.0
# 2020-04   709.0           125.0             2.0          25.0           107.0
# 2020-05  1065.0           150.0             3.0         151.0           108.0
# 2020-06  1027.0           133.0             8.0         165.0           102.0
# 2020-07  1334.0           120.0            10.0         203.0           115.0
# 2020-08  1402.0           128.0             4.0         185.0           106.0
# 2020-09  1578.0           141.0            80.0         183.0           124.0
# ...

# %%
# encontrar a média de serviços por mês no período de vida
# e colocar numa lista

tecnicos = ['henrique.costa', 'henrique.silva', 'diego.morais', 'erivaldo.silva', 'ricardo.neres', 'lucas.coimbra',
          'lander.lucas', 'italo.aires', 'alessandro.almeida', 'cleiton.oliveira', 'douglas.santos',
          'carlos.augusto', 'wendel.silva', 'dejalma.cardoso', 'edvaldo.oliveira', 'leonardo.ferreira',
            'henrique.soares', 'marcelo.martins', 'hainer.sohn', 'wellington.carlos', 'leno.pereira',
            'leonardo.marques', 'thiago.pires', 'diego.dias', 'irineu.souza', 'ivanildo.ribeiro', 
           'valdinei.cavalcante', 'cosme.damasceno','genival.melo','max.oliveira', 'juliano.lopes', 
            'ugleicon.silva', 'guilherme.antunes'
          ]

for tecnico in tecnicos:
    # calcula a média
    media = round(df_total_mensal[tecnico].mean())
    desvio = round(df_total_mensal[tecnico].std())
    mediana = round(df_total_mensal[tecnico].median())

    print(tecnico, '   Média = ', media, '   d = ', desvio, '   mediana = ', mediana)
# Out:
# henrique.costa    Média =  59    d =  73    mediana =  0
# henrique.silva    Média =  14    d =  24    mediana =  3
# diego.morais    Média =  75    d =  57    mediana =  75
# erivaldo.silva    Média =  52    d =  62    mediana =  3
# ricardo.neres    Média =  70    d =  43    mediana =  84
# lucas.coimbra    Média =  27    d =  45    mediana =  0
# lander.lucas    Média =  42    d =  52    mediana =  0
# italo.aires    Média =  57    d =  46    mediana =  52
# alessandro.almeida    Média =  31    d =  55    mediana =  0
# cleiton.oliveira    Média =  62    d =  47    mediana =  74
# douglas.santos    Média =  49    d =  53    mediana =  41
# carlos.augusto    Média =  8    d =  16    mediana =  3
# wendel.silva    Média =  4    d =  6    mediana =  2
# dejalma.cardoso    Média =  18    d =  36    mediana =  0
# edvaldo.oliveira    Média =  42    d =  54    mediana =  0
# leonardo.ferreira    Média =  6    d =  7    mediana =  3
# ...

# %%
from statistics import median, mode, mean, median_grouped, variance, stdev

# Encontrar a média somente dos meses diferentes de zero

tecnicos = ['henrique.costa', 'henrique.silva', 'diego.morais', 'erivaldo.silva', 'ricardo.neres', 'lucas.coimbra',
          'lander.lucas', 'italo.aires', 'alessandro.almeida', 'cleiton.oliveira', 'douglas.santos',
          'carlos.augusto', 'wendel.silva', 'dejalma.cardoso', 'edvaldo.oliveira', 'leonardo.ferreira',
            'henrique.soares', 'marcelo.martins', 'hainer.sohn', 'wellington.carlos', 'leno.pereira',
            'leonardo.marques', 'thiago.pires', 'diego.dias', 'irineu.souza', 'ivanildo.ribeiro', 
           'valdinei.cavalcante', 'cosme.damasceno','genival.melo','max.oliveira', 'juliano.lopes', 
            'ugleicon.silva', 'guilherme.antunes'
          ]

for tecnico in tecnicos:
    # calcula a média
    lista = set(df_total_mensal[tecnico])
    llista =[]
    for n in lista:
        if n >= 88:
            llista.append(n)
    if len(llista) >= 2:       
        media = round(mean(llista))
        desvio = round(stdev(llista))
        mediana = round(median(llista))
        magrup = round(median_grouped(llista))
        moda = round(mode(llista))
        print(tecnico)
        print('           ', 'Média   = ', media)
        print('           ', 'Desvio  = ', desvio)
        print('           ', 'Mediana = ', mediana)
        print('           ', 'Group   = ', magrup)
        print('           ', 'Moda    = ', moda)
# Out:
# henrique.costa
#             Média   =  149
#             Desvio  =  25
#             Mediana =  151
#             Group   =  152
#             Moda    =  128
# diego.morais
#             Média   =  137
#             Desvio  =  37
#             Mediana =  134
#             Group   =  140
#             Moda    =  129
# erivaldo.silva
#             Média   =  127
#             Desvio  =  34
#             Mediana =  112
#             Group   =  114
#             Moda    =  133
# ricardo.neres
#             Média   =  107
#             Desvio  =  12
#             Mediana =  107
#             Group   =  107
#             Moda    =  136
# lucas.coimbra
#             Média   =  106
#             Desvio  =  13
#             Mediana =  103
#             Group   =  103
#             Moda    =  97
# lander.lucas
#             Média   =  118
#             Desvio  =  24
#             Mediana =  108
#             Group   =  108
#             Moda    =  140
# italo.aires
# ...

# %%
# Monta um Gráfico 


from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px
import pandas as pd

#df = df_tec_alg

app = Dash(__name__)
 # Monta o dropdown com a coluna country
app.layout = html.Div([
    html.H1(children='Serviços Totais', style={'textAlign':'center'}),
    dcc.Dropdown(df.Usuario_Designado.unique(), 'none', id='dropdown-selection'),
    dcc.Graph(id='graph-content')
])

@callback(
    Output('graph-content', 'figure'),
    Input('dropdown-selection', 'value')
)
# Define os eixos x e y
def update_graph(value):
    dff = df[df.Usuario_Designado==value]
    return px.bar(dff, x='Ano_Mes', y='Total')

if __name__ == '__main__':
    app.run(debug=True, port=8080)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8080/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# criar lista de técnicos

tecnicos_ativos = set(tecnicos_df['Tecnicos'])

# filtrar df só com os tecnicos

df_tecnicos = df.loc[df['Usuario_Designado'].isin(tecnicos)]

# %%
#Criar Tabela na base com os dados de Tecnicos

# 
# conectar a base

cnx = sqlite3.connect('servicosxis.db')

#Criando a tabela da unidade

tabela = ('serv_total_mensal')

df_total_mensal.to_sql(tabela, cnx, if_exists='replace', index=True)

cnx.close()

# %%
# limpar serv_campo das informações sem o técnico ativo

# Torna a coluna Tecnicos uma lista
tecnicos_ativos = set(tecnicos_df['Tecnicos'])

# mantem somente os itens que contenham 'tecnicos ativos'
df_ativos = df.loc[df['Usuario_Designado'].isin(tecnicos_ativos)]

# %%
#Criar Tabela na base com os dados 

# 
# conectar a base

cnx = sqlite3.connect('servicosxis.db')

#Criando a tabela da unidade

tabela = ('serv_campo_ok')

df_ok.to_sql(tabela, cnx, if_exists='replace', index=True)

cnx.close()

# %%
import numpy as np

# Suponha que 'dados' seja a sua série de dados
dados = [10, 15, 20, 25, 100, 30, 35, 40, 45]

media = np.mean(dados)
desvio_padrao = np.std(dados)

limite_superior = media + 2 * desvio_padrao
limite_inferior = media - 2 * desvio_padrao

outliers = [x for x in dados if x > limite_superior or x < limite_inferior]

print("Outliers:", outliers)

# %%
import numpy as np

# Suponha que 'dados' seja a sua série de dados
dados = [10, 15, 20, 25, 100, 30, 35, 40, 45]

q1 = np.percentile(dados, 25)
q3 = np.percentile(dados, 75)

iqr = q3 - q1
limite_inferior = q1 - 1.5 * iqr
limite_superior = q3 + 1.5 * iqr

outliers = [x for x in dados if x > limite_superior or x < limite_inferior]

print("Outliers:", outliers)

# %%
# Criar uma lista com os dados de entrada para cada serviço de cada unidade para 
# encontrar a melhor distribuição que a representa

# %%
# Criar uma tabela com os dados de performance de cada técnico
# relacionando o número de serviços executados por mês com o número de horas trabalhadas
# considerar: 
#

# %%
import sqlite3
import pandas as pd

# Carrega a tabela servicos da base servicosxis.db para um dataframe

# Cria a conexão
cnx = sqlite3.connect('servicosxis.db')

# carrega tabela servicos em df
df = pd.read_sql_query("SELECT * FROM serv_campo", cnx)

cnx.close()

# %%
""" encontrar uma distribuição estatística que melhor represente uma lista 
de valores usando Python. Uma abordagem comum para fazer isso é ajustar os dados a 
diferentes distribuições de probabilidade e escolher a distribuição que melhor se ajusta
aos seus dados com base em critérios como o coeficiente de determinação (R²), o teste de 
aderência de Kolmogorov-Smirnov ou o critério de informação Akaike (AIC).

Aqui está um exemplo de como fazer isso usando a biblioteca scipy.stats:
"""
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Suponha que você tenha uma lista de valores 'data'
data = [10.2, 11.5, 12.8, 9.7, 11.2, 14.1, 8.5, 10.3, 13.0, 12.1]

# Ajustar os dados a diferentes distribuições
distributions = [stats.norm, stats.expon, stats.gamma, stats.lognorm]

best_fit = None
best_params = None
best_sse = float('inf')

for distribution in distributions:
    params = distribution.fit(data)
    arg = params[:-2]
    loc = params[-2]
    scale = params[-1]
    pdf = distribution.pdf(data, loc=loc, scale=scale, *arg)
    sse = np.sum((pdf - data)**2)
    
    if sse < best_sse:
        best_fit = distribution
        best_params = params
        best_sse = sse

# Agora você tem a melhor distribuição encontrada e seus parâmetros
print("Melhor Distribuição:", best_fit.name)
print("Melhores Parâmetros:", best_params)

# Você pode plotar o histograma dos dados e a PDF da melhor distribuição
plt.hist(data, bins=20, density=True, alpha=0.5, color='b')
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = best_fit.pdf(x, *best_params)
plt.plot(x, p, 'k', linewidth=2)
plt.show()
